# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU, ReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda, GlobalAveragePooling2D
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 50
l = 10
num_filter = 20

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=8)

# %%
input = Input(shape=(img_height, img_width, channel,))

layer1 = BatchNormalization(name='norm_1')(input)
layer1 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(layer1)
layer1 = ReLU()(layer1)
layer1 = BatchNormalization(name='norm_2')(layer1)
layer1 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(layer1)
layer1 = ReLU()(layer1)
layer1 = BatchNormalization(name='norm_3')(layer1)
layer1 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(layer1)
layer1 = ReLU()(layer1)
layer1 = BatchNormalization(name='norm_4')(layer1)
layer1 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_4', use_bias=False)(layer1)
layer1 = ReLU()(layer1)
layer1 = BatchNormalization(name='norm_5')(layer1)
layer1 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(layer1)
layer1 = ReLU()(layer1)
layer1 = MaxPooling2D(pool_size=(2, 2))(layer1)

skip_connection = layer1

layer2 = BatchNormalization(name='norm_6')(layer1)
layer2 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(layer2)
layer2 = ReLU()(layer2)
layer2 = BatchNormalization(name='norm_7')(layer2)
layer2 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_7', use_bias=False)(layer2)
layer2 = ReLU()(layer2)
layer2 = BatchNormalization(name='norm_8')(layer2)
layer2 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(layer2)
layer2 = ReLU()(layer2)
layer2 = BatchNormalization(name='norm_9')(layer2)
layer2 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(layer2)
layer2 = ReLU()(layer2)
layer2 = BatchNormalization(name='norm_10')(layer2)
layer2 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_10', use_bias=False)(layer2)
layer2 = ReLU()(layer2)
layer2 = MaxPooling2D(pool_size=(2, 2))(layer2)

layer3 = BatchNormalization(name='norm_11')(layer2)
layer3 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(layer3)
layer3 = ReLU()(layer3)
layer3 = BatchNormalization(name='norm_12')(layer3)
layer3 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_12', use_bias=False)(layer3)
layer3 = ReLU()(layer3)
layer3 = BatchNormalization(name='norm_13')(layer3)
layer3 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(layer3)
layer3 = ReLU()(layer3)
layer3 = BatchNormalization(name='norm_14')(layer3)
layer3 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(layer3)
layer3 = ReLU()(layer3)
layer3 = BatchNormalization(name='norm_15')(layer3)
layer3 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_15', use_bias=False)(layer3)
layer3 = ReLU()(layer3)
layer3 = MaxPooling2D(pool_size=(2, 2))(layer3)

layer4 = BatchNormalization(name='norm_16')(layer3)
layer4 = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(layer4)
layer4 = ReLU()(layer4)
layer4 = BatchNormalization(name='norm_17')(layer4)
layer4 = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_17', use_bias=False)(layer4)
layer4 = ReLU()(layer4)
layer4 = BatchNormalization(name='norm_18')(layer4)
layer4 = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(layer4)
layer4 = ReLU()(layer4)
layer4 = BatchNormalization(name='norm_19')(layer4)
layer4 = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(layer4)
layer4 = ReLU()(layer4)
layer4 = BatchNormalization(name='norm_20')(layer4)
layer4 = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(layer4)
layer4 = ReLU()(layer4)
layer4 = MaxPooling2D(pool_size=(2, 2))(layer4)

skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = ReLU()(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

layer5 = concatenate([skip_connection, layer4])

layer6 = Conv2D(10, (1,1), strides=(1,1), name='conv_22', use_bias=False)(layer5)

#layer7 = MaxPooling2D(pool_size=(2, 2))(layer6)

layer7 = GlobalAveragePooling2D()(layer6)

#layer8 = Flatten()(layer7)

output = Activation('softmax')(layer7)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_32 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 3)    12          input_32[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         norm_1[0][0]
# __________________________________________________________________________________________________
# re_lu_648 (ReLU)                (None, 32, 32, 32)   0           conv_1[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 32, 32, 32)   128         re_lu_648[0][0]
# ...

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 223s 4ms/step - loss: 1.3790 - acc: 0.5065 - val_loss: 2.7669 - val_acc: 0.4084
# Epoch 2/50
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.8840 - acc: 0.6904 - val_loss: 1.4199 - val_acc: 0.6211
# Epoch 3/50
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.6978 - acc: 0.7587 - val_loss: 0.9738 - val_acc: 0.7052
# Epoch 4/50
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.5643 - acc: 0.8048 - val_loss: 0.7878 - val_acc: 0.7596
# Epoch 5/50
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.4722 - acc: 0.8372 - val_loss: 0.7631 - val_acc: 0.7613
# Epoch 6/50
# 50000/50000 [==============================] - 202s 4ms/step - loss: 0.3923 - acc: 0.8642 - val_loss: 0.6663 - val_acc: 0.7914
# Epoch 7/50
# ...

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("3C_Latest.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 18s 2ms/step
# Test loss: 1.08793474766016
# Test accuracy: 0.824
# Saved the model to disk

# %%
model.save_weights("3C_Latestmodel.h5")
print("Saved the model to disk")
from google.colab import files

files.download('3C_Latestmodel.h5')
# Out:
# Saved the model to disk
